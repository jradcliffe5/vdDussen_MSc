# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
import corner
from scipy.stats import norm
from astropy.io import fits
import math
# %matplotlib inline

# %%
#plt.rcParams['figure.figsize'] = (20,10)


hdu = fits.open("goodsn-42-G141_01060.2D.fits")
flux = hdu['SCI'].data[22,110:140]
wavelength = hdu['SCI'].data[20:25,120]  #pixels representing wavelength

# To find: p and m2. I have vr: v2/v1 and the error there in. The model function calculates a value from the equation for binary systems and should input different random values for p and m2 as defined in their prior range. 
#the output must be compared to the prior for vr and must be close to the vr value.

#start by defining the model function
v2=-3.75e11 #km/year
v1=21713976790.253414 #km/year
delta_v=abs(v1-v2)
print('DeltaV=', delta_v, 'km/year')
G=1.327e11 #km^3 (solar mass)^-1 years^-2
#from log10(log stellar mass/Msun) = 10.54, stellar mass (stm) aka m1+m2= 3.47 × 10^10  solar masses
stm= 1e7 #kg

def smbh2_model(theta,stm=stm):
    p,m2,m1=theta
    sin3=2/3 #estimate
    numerator = (m1+m2) * 2 * math.pi * G * sin3
    denominator = p
    cube_root = (numerator / denominator) ** (1/3)
    delta_v = cube_root

    return delta_v
#We now need a function referred to as lnlike().This function takes as an argument theta as well as the x,y,  and yerr of the actual theta. It should return a number corresponding to how good a fit the model is to my data given a set of parameters
#weighted by the error in my data points (the error in v_offset calcs)
# y is the value of vr and yerr the value of the error in the calcs. ?

def lnlike(theta, x, y, yerr):
    return -0.5 * np.sum(((y -smbh2_model(theta,stm=stm))/yerr) ** 2)

#lnprior function is used to check that all variables are within their priors (here the priors are set)
#emcee requires 0.0 returned if all priors are satisfied. if not function returns -np.inf
def lnprior(theta):
    p, m2, m1 =theta
    if (1e5<p< 1e8) and (1e5<m2< 1e7) and (1e6<m1< 1e8) and (1e6<m1+m2<1e8) and (1e10<smbh2_model(theta,stm=stm)<21e11):
        return 0.0

    return -np.inf 
#one model to rule them all
# lnprob combines the above steps by running lnprior and if np.inf is returned passe
def lnprob(theta, x, y, yerr):
    lp=lnprior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(theta, x, y, yerr)
    

#We also need to set a value for nwalkers, which determines how many walkers are initialized in our MCMC: use 1000 (arbitrary)

#We need a variable called initial, which is an initial set of guesses (this will be the first theta, where the MCMC starts).

#Finally we need p0, which is the methodology of stepping from one place to a grid to the next 
yerr_val=10000
#err and data left out
data=(wavelength, flux, yerr_val)
nwalkers = 1000
niter = 1000
initial = np.array([1e7, 1e6, 1e7])
ndim = len(initial)
# Randomly sample initial state for walkers (assuming uniform priors)
p0 = [np.array(initial) + 100 * np.random.randn(ndim) for i in range(nwalkers)]




#p0 = random_initialization(nwalkers, ndim, lower_bounds, upper_bounds)
def main(p0,nwalkers,niter,ndim,lnprob,data):
    sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=data)
    print(data)
    print("Running burn-in...")
    p0, _, _ = sampler.run_mcmc(p0, 100)
    sampler.reset()

    print("Running production...")
    pos, prob, state = sampler.run_mcmc(p0, niter)


    return sampler, pos, prob, state
# Out:
# DeltaV= 396713976790.2534 km/year

# %%
 sampler, pos, prob, state = main(p0,nwalkers,niter,ndim,lnprob,data)
# Out:
# (array([0.12441757, 0.11663651, 0.127021  , 0.10297639, 0.09852233],
#       dtype='>f8'), array([0.07025735, 0.10124537, 0.08127703, 0.08352374, 0.0865227 ,
#        0.08374514, 0.07721471, 0.07999526, 0.083603  , 0.09660716,
#        0.127021  , 0.10731463, 0.15107947, 0.1955422 , 0.20785707,
#        0.17753332, 0.20437395, 0.25618986, 0.29427448, 0.32659609,
#        0.19281928, 0.12941686, 0.09991945, 0.09852149, 0.0953414 ,
#        0.07620114, 0.07649414, 0.08685088, 0.07438385, 0.0758074 ],
#       dtype='>f8'), 10000)
# Running burn-in...
# /usr/local/lib/python3.11/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in scalar subtract
#   lnpdiff = f + nlp - state.log_prob[j]
# Running production...

# %%
samples=sampler.flatchain
diff= samples[:,1]-samples[:,2]

# %%
plt.hist(diff)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
samples[np.argmax(sampler.flatlnprobability)]
log_samples=np.log(samples)
labels = ['log(p)','log(m2)','log(m1)']
fig = corner.corner(log_samples,show_titles=True,labels=labels,plot_datapoints=True,quantiles=[0.16, 0.5, 0.84])
print('nwalkers is', nwalkers)
print('niter is', niter)
# Out:
# nwalkers is 1000
# niter is 1000

# %%
# Assuming 'sampler' is your emcee sampler object
acceptance_fractions = sampler.acceptance_fraction

# Print the mean acceptance fraction with one decimal place
print("Mean acceptance fraction: {:.5f}".format(np.mean(acceptance_fractions)))

# Print the acceptance fraction for each walker with two decimal places
for i, af in enumerate(acceptance_fractions):
    print(f"Walker {i+1} acceptance fraction: {af:.2f}")
# Out:
# Mean acceptance fraction: 0.0
# Walker 1 acceptance fraction: 0.00
# Walker 2 acceptance fraction: 0.00
# Walker 3 acceptance fraction: 0.00
# Walker 4 acceptance fraction: 0.00
# Walker 5 acceptance fraction: 0.00
# Walker 6 acceptance fraction: 0.00
# Walker 7 acceptance fraction: 0.00
# Walker 8 acceptance fraction: 0.00
# Walker 9 acceptance fraction: 0.00
# Walker 10 acceptance fraction: 0.00
# Walker 11 acceptance fraction: 0.00
# Walker 12 acceptance fraction: 0.00
# Walker 13 acceptance fraction: 0.00
# Walker 14 acceptance fraction: 0.00
# Walker 15 acceptance fraction: 0.00
# Walker 16 acceptance fraction: 0.00
# Walker 17 acceptance fraction: 0.00
# Walker 18 acceptance fraction: 0.00
# Walker 19 acceptance fraction: 0.00
# Walker 20 acceptance fraction: 0.00
# Walker 21 acceptance fraction: 0.00
# Walker 22 acceptance fraction: 0.00
# Walker 23 acceptance fraction: 0.00
# Walker 24 acceptance fraction: 0.00
# Walker 25 acceptance fraction: 0.00
# Walker 26 acceptance fraction: 0.00
# Walker 27 acceptance fraction: 0.00
# Walker 28 acceptance fraction: 0.00
# Walker 29 acceptance fraction: 0.00
# Walker 30 acceptance fraction: 0.00
# Walker 31 acceptance fraction: 0.00
# Walker 32 acceptance fraction: 0.00
# Walker 33 acceptance fraction: 0.00
# Walker 34 acceptance fraction: 0.00
# Walker 35 acceptance fraction: 0.00
# Walker 36 acceptance fraction: 0.00
# Walker 37 acceptance fraction: 0.00
# Walker 38 acceptance fraction: 0.00
# Walker 39 acceptance fraction: 0.00
# Walker 40 acceptance fraction: 0.00
# Walker 41 acceptance fraction: 0.00
# Walker 42 acceptance fraction: 0.00
# Walker 43 acceptance fraction: 0.00
# Walker 44 acceptance fraction: 0.00
# Walker 45 acceptance fraction: 0.00
# Walker 46 acceptance fraction: 0.00
# Walker 47 acceptance fraction: 0.00
# Walker 48 acceptance fraction: 0.00
# Walker 49 acceptance fraction: 0.00
# Walker 50 acceptance fraction: 0.00
# Walker 51 acceptance fraction: 0.00
# Walker 52 acceptance fraction: 0.00
# Walker 53 acceptance fraction: 0.00
# Walker 54 acceptance fraction: 0.00
# Walker 55 acceptance fraction: 0.00
# Walker 56 acceptance fraction: 0.00
# Walker 57 acceptance fraction: 0.00
# Walker 58 acceptance fraction: 0.00
# Walker 59 acceptance fraction: 0.00
# Walker 60 acceptance fraction: 0.00
# Walker 61 acceptance fraction: 0.00
# Walker 62 acceptance fraction: 0.00
# Walker 63 acceptance fraction: 0.00
# Walker 64 acceptance fraction: 0.00
# Walker 65 acceptance fraction: 0.00
# Walker 66 acceptance fraction: 0.00
# Walker 67 acceptance fraction: 0.00
# Walker 68 acceptance fraction: 0.00
# Walker 69 acceptance fraction: 0.00
# Walker 70 acceptance fraction: 0.00
# Walker 71 acceptance fraction: 0.00
# Walker 72 acceptance fraction: 0.00
# Walker 73 acceptance fraction: 0.00
# Walker 74 acceptance fraction: 0.00
# Walker 75 acceptance fraction: 0.00
# Walker 76 acceptance fraction: 0.00
# Walker 77 acceptance fraction: 0.00
# Walker 78 acceptance fraction: 0.00
# Walker 79 acceptance fraction: 0.00
# Walker 80 acceptance fraction: 0.00
# Walker 81 acceptance fraction: 0.00
# Walker 82 acceptance fraction: 0.00
# Walker 83 acceptance fraction: 0.00
# Walker 84 acceptance fraction: 0.00
# Walker 85 acceptance fraction: 0.00
# Walker 86 acceptance fraction: 0.00
# Walker 87 acceptance fraction: 0.00
# Walker 88 acceptance fraction: 0.00
# Walker 89 acceptance fraction: 0.00
# Walker 90 acceptance fraction: 0.00
# Walker 91 acceptance fraction: 0.00
# Walker 92 acceptance fraction: 0.00
# Walker 93 acceptance fraction: 0.00
# Walker 94 acceptance fraction: 0.00
# Walker 95 acceptance fraction: 0.00
# Walker 96 acceptance fraction: 0.00
# Walker 97 acceptance fraction: 0.00
# Walker 98 acceptance fraction: 0.00
# Walker 99 acceptance fraction: 0.00
# Walker 100 acceptance fraction: 0.00
# Walker 101 acceptance fraction: 0.00
# Walker 102 acceptance fraction: 0.00
# Walker 103 acceptance fraction: 0.00
# Walker 104 acceptance fraction: 0.00
# Walker 105 acceptance fraction: 0.00
# Walker 106 acceptance fraction: 0.00
# Walker 107 acceptance fraction: 0.00
# Walker 108 acceptance fraction: 0.00
# Walker 109 acceptance fraction: 0.00
# Walker 110 acceptance fraction: 0.00
# Walker 111 acceptance fraction: 0.00
# Walker 112 acceptance fraction: 0.00
# Walker 113 acceptance fraction: 0.00
# Walker 114 acceptance fraction: 0.00
# Walker 115 acceptance fraction: 0.00
# Walker 116 acceptance fraction: 0.00
# Walker 117 acceptance fraction: 0.00
# Walker 118 acceptance fraction: 0.00
# Walker 119 acceptance fraction: 0.00
# Walker 120 acceptance fraction: 0.00
# Walker 121 acceptance fraction: 0.00
# Walker 122 acceptance fraction: 0.00
# Walker 123 acceptance fraction: 0.00
# Walker 124 acceptance fraction: 0.00
# Walker 125 acceptance fraction: 0.00
# Walker 126 acceptance fraction: 0.00
# Walker 127 acceptance fraction: 0.00
# Walker 128 acceptance fraction: 0.00
# Walker 129 acceptance fraction: 0.00
# Walker 130 acceptance fraction: 0.00
# Walker 131 acceptance fraction: 0.00
# Walker 132 acceptance fraction: 0.00
# Walker 133 acceptance fraction: 0.00
# Walker 134 acceptance fraction: 0.00
# Walker 135 acceptance fraction: 0.00
# Walker 136 acceptance fraction: 0.00
# Walker 137 acceptance fraction: 0.00
# Walker 138 acceptance fraction: 0.00
# Walker 139 acceptance fraction: 0.00
# Walker 140 acceptance fraction: 0.00
# Walker 141 acceptance fraction: 0.00
# Walker 142 acceptance fraction: 0.00
# Walker 143 acceptance fraction: 0.00
# Walker 144 acceptance fraction: 0.00
# Walker 145 acceptance fraction: 0.00
# Walker 146 acceptance fraction: 0.00
# Walker 147 acceptance fraction: 0.00
# Walker 148 acceptance fraction: 0.00
# Walker 149 acceptance fraction: 0.00
# Walker 150 acceptance fraction: 0.00
# Walker 151 acceptance fraction: 0.00
# Walker 152 acceptance fraction: 0.00
# Walker 153 acceptance fraction: 0.00
# Walker 154 acceptance fraction: 0.00
# Walker 155 acceptance fraction: 0.00
# Walker 156 acceptance fraction: 0.00
# Walker 157 acceptance fraction: 0.00
# Walker 158 acceptance fraction: 0.00
# Walker 159 acceptance fraction: 0.00
# Walker 160 acceptance fraction: 0.00
# Walker 161 acceptance fraction: 0.00
# Walker 162 acceptance fraction: 0.00
# Walker 163 acceptance fraction: 0.00
# Walker 164 acceptance fraction: 0.00
# Walker 165 acceptance fraction: 0.00
# Walker 166 acceptance fraction: 0.00
# Walker 167 acceptance fraction: 0.00
# Walker 168 acceptance fraction: 0.00
# Walker 169 acceptance fraction: 0.00
# Walker 170 acceptance fraction: 0.00
# Walker 171 acceptance fraction: 0.00
# Walker 172 acceptance fraction: 0.00
# Walker 173 acceptance fraction: 0.00
# Walker 174 acceptance fraction: 0.00
# Walker 175 acceptance fraction: 0.00
# Walker 176 acceptance fraction: 0.00
# Walker 177 acceptance fraction: 0.00
# Walker 178 acceptance fraction: 0.00
# Walker 179 acceptance fraction: 0.00
# Walker 180 acceptance fraction: 0.00
# Walker 181 acceptance fraction: 0.00
# Walker 182 acceptance fraction: 0.00
# Walker 183 acceptance fraction: 0.00
# Walker 184 acceptance fraction: 0.00
# Walker 185 acceptance fraction: 0.00
# Walker 186 acceptance fraction: 0.00
# Walker 187 acceptance fraction: 0.00
# Walker 188 acceptance fraction: 0.00
# Walker 189 acceptance fraction: 0.00
# Walker 190 acceptance fraction: 0.00
# Walker 191 acceptance fraction: 0.00
# Walker 192 acceptance fraction: 0.00
# Walker 193 acceptance fraction: 0.00
# Walker 194 acceptance fraction: 0.00
# Walker 195 acceptance fraction: 0.00
# Walker 196 acceptance fraction: 0.00
# Walker 197 acceptance fraction: 0.00
# Walker 198 acceptance fraction: 0.00
# Walker 199 acceptance fraction: 0.00
# Walker 200 acceptance fraction: 0.00
# Walker 201 acceptance fraction: 0.00
# Walker 202 acceptance fraction: 0.00
# Walker 203 acceptance fraction: 0.00
# Walker 204 acceptance fraction: 0.00
# Walker 205 acceptance fraction: 0.00
# Walker 206 acceptance fraction: 0.00
# Walker 207 acceptance fraction: 0.00
# Walker 208 acceptance fraction: 0.00
# Walker 209 acceptance fraction: 0.00
# Walker 210 acceptance fraction: 0.00
# Walker 211 acceptance fraction: 0.00
# Walker 212 acceptance fraction: 0.00
# Walker 213 acceptance fraction: 0.00
# Walker 214 acceptance fraction: 0.00
# Walker 215 acceptance fraction: 0.00
# Walker 216 acceptance fraction: 0.00
# Walker 217 acceptance fraction: 0.00
# Walker 218 acceptance fraction: 0.00
# Walker 219 acceptance fraction: 0.00
# Walker 220 acceptance fraction: 0.00
# Walker 221 acceptance fraction: 0.00
# Walker 222 acceptance fraction: 0.00
# Walker 223 acceptance fraction: 0.00
# Walker 224 acceptance fraction: 0.00
# Walker 225 acceptance fraction: 0.00
# Walker 226 acceptance fraction: 0.00
# Walker 227 acceptance fraction: 0.00
# Walker 228 acceptance fraction: 0.00
# Walker 229 acceptance fraction: 0.00
# Walker 230 acceptance fraction: 0.00
# Walker 231 acceptance fraction: 0.00
# Walker 232 acceptance fraction: 0.00
# Walker 233 acceptance fraction: 0.00
# Walker 234 acceptance fraction: 0.00
# Walker 235 acceptance fraction: 0.00
# Walker 236 acceptance fraction: 0.00
# Walker 237 acceptance fraction: 0.00
# Walker 238 acceptance fraction: 0.00
# Walker 239 acceptance fraction: 0.00
# Walker 240 acceptance fraction: 0.00
# Walker 241 acceptance fraction: 0.00
# Walker 242 acceptance fraction: 0.00
# Walker 243 acceptance fraction: 0.00
# Walker 244 acceptance fraction: 0.00
# Walker 245 acceptance fraction: 0.00
# Walker 246 acceptance fraction: 0.00
# Walker 247 acceptance fraction: 0.00
# Walker 248 acceptance fraction: 0.00
# Walker 249 acceptance fraction: 0.00
# Walker 250 acceptance fraction: 0.00
# Walker 251 acceptance fraction: 0.00
# Walker 252 acceptance fraction: 0.00
# Walker 253 acceptance fraction: 0.00
# Walker 254 acceptance fraction: 0.00
# Walker 255 acceptance fraction: 0.00
# Walker 256 acceptance fraction: 0.00
# Walker 257 acceptance fraction: 0.00
# Walker 258 acceptance fraction: 0.00
# Walker 259 acceptance fraction: 0.00
# Walker 260 acceptance fraction: 0.00
# Walker 261 acceptance fraction: 0.00
# Walker 262 acceptance fraction: 0.00
# Walker 263 acceptance fraction: 0.00
# Walker 264 acceptance fraction: 0.00
# Walker 265 acceptance fraction: 0.00
# Walker 266 acceptance fraction: 0.00
# Walker 267 acceptance fraction: 0.00
# Walker 268 acceptance fraction: 0.00
# Walker 269 acceptance fraction: 0.00
# Walker 270 acceptance fraction: 0.00
# Walker 271 acceptance fraction: 0.00
# Walker 272 acceptance fraction: 0.00
# Walker 273 acceptance fraction: 0.00
# Walker 274 acceptance fraction: 0.00
# Walker 275 acceptance fraction: 0.00
# Walker 276 acceptance fraction: 0.00
# Walker 277 acceptance fraction: 0.00
# Walker 278 acceptance fraction: 0.00
# Walker 279 acceptance fraction: 0.00
# Walker 280 acceptance fraction: 0.00
# Walker 281 acceptance fraction: 0.00
# Walker 282 acceptance fraction: 0.00
# Walker 283 acceptance fraction: 0.00
# Walker 284 acceptance fraction: 0.00
# Walker 285 acceptance fraction: 0.00
# Walker 286 acceptance fraction: 0.00
# Walker 287 acceptance fraction: 0.00
# Walker 288 acceptance fraction: 0.00
# Walker 289 acceptance fraction: 0.00
# Walker 290 acceptance fraction: 0.00
# Walker 291 acceptance fraction: 0.00
# Walker 292 acceptance fraction: 0.00
# Walker 293 acceptance fraction: 0.00
# Walker 294 acceptance fraction: 0.00
# Walker 295 acceptance fraction: 0.00
# Walker 296 acceptance fraction: 0.00
# Walker 297 acceptance fraction: 0.00
# Walker 298 acceptance fraction: 0.00
# Walker 299 acceptance fraction: 0.00
# Walker 300 acceptance fraction: 0.00
# Walker 301 acceptance fraction: 0.00
# Walker 302 acceptance fraction: 0.00
# Walker 303 acceptance fraction: 0.00
# Walker 304 acceptance fraction: 0.00
# Walker 305 acceptance fraction: 0.00
# Walker 306 acceptance fraction: 0.00
# Walker 307 acceptance fraction: 0.00
# Walker 308 acceptance fraction: 0.00
# Walker 309 acceptance fraction: 0.00
# Walker 310 acceptance fraction: 0.00
# Walker 311 acceptance fraction: 0.00
# Walker 312 acceptance fraction: 0.00
# Walker 313 acceptance fraction: 0.00
# Walker 314 acceptance fraction: 0.00
# Walker 315 acceptance fraction: 0.00
# Walker 316 acceptance fraction: 0.00
# Walker 317 acceptance fraction: 0.00
# Walker 318 acceptance fraction: 0.00
# Walker 319 acceptance fraction: 0.00
# Walker 320 acceptance fraction: 0.00
# Walker 321 acceptance fraction: 0.00
# Walker 322 acceptance fraction: 0.00
# Walker 323 acceptance fraction: 0.00
# Walker 324 acceptance fraction: 0.00
# Walker 325 acceptance fraction: 0.00
# Walker 326 acceptance fraction: 0.00
# Walker 327 acceptance fraction: 0.00
# Walker 328 acceptance fraction: 0.00
# Walker 329 acceptance fraction: 0.00
# Walker 330 acceptance fraction: 0.00
# Walker 331 acceptance fraction: 0.00
# Walker 332 acceptance fraction: 0.00
# Walker 333 acceptance fraction: 0.00
# Walker 334 acceptance fraction: 0.00
# Walker 335 acceptance fraction: 0.00
# Walker 336 acceptance fraction: 0.00
# Walker 337 acceptance fraction: 0.00
# Walker 338 acceptance fraction: 0.00
# Walker 339 acceptance fraction: 0.00
# Walker 340 acceptance fraction: 0.00
# Walker 341 acceptance fraction: 0.00
# Walker 342 acceptance fraction: 0.00
# Walker 343 acceptance fraction: 0.00
# Walker 344 acceptance fraction: 0.00
# Walker 345 acceptance fraction: 0.00
# Walker 346 acceptance fraction: 0.00
# Walker 347 acceptance fraction: 0.00
# Walker 348 acceptance fraction: 0.00
# Walker 349 acceptance fraction: 0.00
# Walker 350 acceptance fraction: 0.00
# Walker 351 acceptance fraction: 0.00
# Walker 352 acceptance fraction: 0.00
# Walker 353 acceptance fraction: 0.00
# Walker 354 acceptance fraction: 0.00
# Walker 355 acceptance fraction: 0.00
# Walker 356 acceptance fraction: 0.00
# Walker 357 acceptance fraction: 0.00
# Walker 358 acceptance fraction: 0.00
# Walker 359 acceptance fraction: 0.00
# Walker 360 acceptance fraction: 0.00
# Walker 361 acceptance fraction: 0.00
# Walker 362 acceptance fraction: 0.00
# Walker 363 acceptance fraction: 0.00
# Walker 364 acceptance fraction: 0.00
# Walker 365 acceptance fraction: 0.00
# Walker 366 acceptance fraction: 0.00
# Walker 367 acceptance fraction: 0.00
# Walker 368 acceptance fraction: 0.00
# Walker 369 acceptance fraction: 0.00
# Walker 370 acceptance fraction: 0.00
# Walker 371 acceptance fraction: 0.00
# Walker 372 acceptance fraction: 0.00
# Walker 373 acceptance fraction: 0.00
# Walker 374 acceptance fraction: 0.00
# Walker 375 acceptance fraction: 0.00
# Walker 376 acceptance fraction: 0.00
# Walker 377 acceptance fraction: 0.00
# Walker 378 acceptance fraction: 0.00
# Walker 379 acceptance fraction: 0.00
# Walker 380 acceptance fraction: 0.00
# Walker 381 acceptance fraction: 0.00
# Walker 382 acceptance fraction: 0.00
# Walker 383 acceptance fraction: 0.00
# Walker 384 acceptance fraction: 0.00
# Walker 385 acceptance fraction: 0.00
# Walker 386 acceptance fraction: 0.00
# Walker 387 acceptance fraction: 0.00
# Walker 388 acceptance fraction: 0.00
# Walker 389 acceptance fraction: 0.00
# Walker 390 acceptance fraction: 0.00
# Walker 391 acceptance fraction: 0.00
# Walker 392 acceptance fraction: 0.00
# Walker 393 acceptance fraction: 0.00
# Walker 394 acceptance fraction: 0.00
# Walker 395 acceptance fraction: 0.00
# Walker 396 acceptance fraction: 0.00
# Walker 397 acceptance fraction: 0.00
# Walker 398 acceptance fraction: 0.00
# Walker 399 acceptance fraction: 0.00
# Walker 400 acceptance fraction: 0.00
# Walker 401 acceptance fraction: 0.00
# Walker 402 acceptance fraction: 0.00
# Walker 403 acceptance fraction: 0.00
# Walker 404 acceptance fraction: 0.00
# Walker 405 acceptance fraction: 0.00
# Walker 406 acceptance fraction: 0.00
# Walker 407 acceptance fraction: 0.00
# Walker 408 acceptance fraction: 0.00
# Walker 409 acceptance fraction: 0.00
# Walker 410 acceptance fraction: 0.00
# Walker 411 acceptance fraction: 0.00
# Walker 412 acceptance fraction: 0.00
# Walker 413 acceptance fraction: 0.00
# Walker 414 acceptance fraction: 0.00
# Walker 415 acceptance fraction: 0.00
# Walker 416 acceptance fraction: 0.00
# Walker 417 acceptance fraction: 0.00
# Walker 418 acceptance fraction: 0.00
# Walker 419 acceptance fraction: 0.00
# Walker 420 acceptance fraction: 0.00
# Walker 421 acceptance fraction: 0.00
# Walker 422 acceptance fraction: 0.00
# Walker 423 acceptance fraction: 0.00
# Walker 424 acceptance fraction: 0.00
# Walker 425 acceptance fraction: 0.00
# Walker 426 acceptance fraction: 0.00
# Walker 427 acceptance fraction: 0.00
# Walker 428 acceptance fraction: 0.00
# Walker 429 acceptance fraction: 0.00
# Walker 430 acceptance fraction: 0.00
# Walker 431 acceptance fraction: 0.00
# Walker 432 acceptance fraction: 0.00
# Walker 433 acceptance fraction: 0.00
# Walker 434 acceptance fraction: 0.00
# Walker 435 acceptance fraction: 0.00
# Walker 436 acceptance fraction: 0.00
# Walker 437 acceptance fraction: 0.00
# Walker 438 acceptance fraction: 0.00
# Walker 439 acceptance fraction: 0.00
# Walker 440 acceptance fraction: 0.00
# Walker 441 acceptance fraction: 0.00
# Walker 442 acceptance fraction: 0.00
# Walker 443 acceptance fraction: 0.00
# Walker 444 acceptance fraction: 0.00
# Walker 445 acceptance fraction: 0.00
# Walker 446 acceptance fraction: 0.00
# Walker 447 acceptance fraction: 0.00
# Walker 448 acceptance fraction: 0.00
# Walker 449 acceptance fraction: 0.00
# Walker 450 acceptance fraction: 0.00
# Walker 451 acceptance fraction: 0.00
# Walker 452 acceptance fraction: 0.00
# Walker 453 acceptance fraction: 0.00
# Walker 454 acceptance fraction: 0.00
# Walker 455 acceptance fraction: 0.00
# Walker 456 acceptance fraction: 0.00
# Walker 457 acceptance fraction: 0.00
# Walker 458 acceptance fraction: 0.00
# Walker 459 acceptance fraction: 0.00
# Walker 460 acceptance fraction: 0.00
# Walker 461 acceptance fraction: 0.00
# Walker 462 acceptance fraction: 0.00
# Walker 463 acceptance fraction: 0.00
# Walker 464 acceptance fraction: 0.00
# Walker 465 acceptance fraction: 0.00
# Walker 466 acceptance fraction: 0.00
# Walker 467 acceptance fraction: 0.00
# Walker 468 acceptance fraction: 0.00
# Walker 469 acceptance fraction: 0.00
# Walker 470 acceptance fraction: 0.00
# Walker 471 acceptance fraction: 0.00
# Walker 472 acceptance fraction: 0.00
# Walker 473 acceptance fraction: 0.00
# Walker 474 acceptance fraction: 0.00
# Walker 475 acceptance fraction: 0.00
# Walker 476 acceptance fraction: 0.00
# Walker 477 acceptance fraction: 0.00
# Walker 478 acceptance fraction: 0.00
# Walker 479 acceptance fraction: 0.00
# Walker 480 acceptance fraction: 0.00
# Walker 481 acceptance fraction: 0.00
# Walker 482 acceptance fraction: 0.00
# Walker 483 acceptance fraction: 0.00
# Walker 484 acceptance fraction: 0.00
# Walker 485 acceptance fraction: 0.00
# Walker 486 acceptance fraction: 0.00
# Walker 487 acceptance fraction: 0.00
# Walker 488 acceptance fraction: 0.00
# Walker 489 acceptance fraction: 0.00
# Walker 490 acceptance fraction: 0.00
# Walker 491 acceptance fraction: 0.00
# Walker 492 acceptance fraction: 0.00
# Walker 493 acceptance fraction: 0.00
# Walker 494 acceptance fraction: 0.00
# Walker 495 acceptance fraction: 0.00
# Walker 496 acceptance fraction: 0.00
# Walker 497 acceptance fraction: 0.00
# Walker 498 acceptance fraction: 0.00
# Walker 499 acceptance fraction: 0.00
# Walker 500 acceptance fraction: 0.00
# Walker 501 acceptance fraction: 0.00
# Walker 502 acceptance fraction: 0.00
# Walker 503 acceptance fraction: 0.00
# Walker 504 acceptance fraction: 0.00
# Walker 505 acceptance fraction: 0.00
# Walker 506 acceptance fraction: 0.00
# Walker 507 acceptance fraction: 0.00
# Walker 508 acceptance fraction: 0.00
# Walker 509 acceptance fraction: 0.00
# Walker 510 acceptance fraction: 0.00
# Walker 511 acceptance fraction: 0.00
# Walker 512 acceptance fraction: 0.00
# Walker 513 acceptance fraction: 0.00
# Walker 514 acceptance fraction: 0.00
# Walker 515 acceptance fraction: 0.00
# Walker 516 acceptance fraction: 0.00
# Walker 517 acceptance fraction: 0.00
# Walker 518 acceptance fraction: 0.00
# Walker 519 acceptance fraction: 0.00
# Walker 520 acceptance fraction: 0.00
# Walker 521 acceptance fraction: 0.00
# Walker 522 acceptance fraction: 0.00
# Walker 523 acceptance fraction: 0.00
# Walker 524 acceptance fraction: 0.00
# Walker 525 acceptance fraction: 0.00
# Walker 526 acceptance fraction: 0.00
# Walker 527 acceptance fraction: 0.00
# Walker 528 acceptance fraction: 0.00
# Walker 529 acceptance fraction: 0.00
# Walker 530 acceptance fraction: 0.00
# Walker 531 acceptance fraction: 0.00
# Walker 532 acceptance fraction: 0.00
# Walker 533 acceptance fraction: 0.00
# Walker 534 acceptance fraction: 0.00
# Walker 535 acceptance fraction: 0.00
# Walker 536 acceptance fraction: 0.00
# Walker 537 acceptance fraction: 0.00
# Walker 538 acceptance fraction: 0.00
# Walker 539 acceptance fraction: 0.00
# Walker 540 acceptance fraction: 0.00
# Walker 541 acceptance fraction: 0.00
# Walker 542 acceptance fraction: 0.00
# Walker 543 acceptance fraction: 0.00
# Walker 544 acceptance fraction: 0.00
# Walker 545 acceptance fraction: 0.00
# Walker 546 acceptance fraction: 0.00
# Walker 547 acceptance fraction: 0.00
# Walker 548 acceptance fraction: 0.00
# Walker 549 acceptance fraction: 0.00
# Walker 550 acceptance fraction: 0.00
# Walker 551 acceptance fraction: 0.00
# Walker 552 acceptance fraction: 0.00
# Walker 553 acceptance fraction: 0.00
# Walker 554 acceptance fraction: 0.00
# Walker 555 acceptance fraction: 0.00
# Walker 556 acceptance fraction: 0.00
# Walker 557 acceptance fraction: 0.00
# Walker 558 acceptance fraction: 0.00
# Walker 559 acceptance fraction: 0.00
# Walker 560 acceptance fraction: 0.00
# Walker 561 acceptance fraction: 0.00
# Walker 562 acceptance fraction: 0.00
# Walker 563 acceptance fraction: 0.00
# Walker 564 acceptance fraction: 0.00
# Walker 565 acceptance fraction: 0.00
# Walker 566 acceptance fraction: 0.00
# Walker 567 acceptance fraction: 0.00
# Walker 568 acceptance fraction: 0.00
# Walker 569 acceptance fraction: 0.00
# Walker 570 acceptance fraction: 0.00
# Walker 571 acceptance fraction: 0.00
# Walker 572 acceptance fraction: 0.00
# Walker 573 acceptance fraction: 0.00
# Walker 574 acceptance fraction: 0.00
# Walker 575 acceptance fraction: 0.00
# Walker 576 acceptance fraction: 0.00
# Walker 577 acceptance fraction: 0.00
# Walker 578 acceptance fraction: 0.00
# Walker 579 acceptance fraction: 0.00
# Walker 580 acceptance fraction: 0.00
# Walker 581 acceptance fraction: 0.00
# Walker 582 acceptance fraction: 0.00
# Walker 583 acceptance fraction: 0.00
# Walker 584 acceptance fraction: 0.00
# Walker 585 acceptance fraction: 0.00
# Walker 586 acceptance fraction: 0.00
# Walker 587 acceptance fraction: 0.00
# Walker 588 acceptance fraction: 0.00
# Walker 589 acceptance fraction: 0.00
# Walker 590 acceptance fraction: 0.00
# Walker 591 acceptance fraction: 0.00
# Walker 592 acceptance fraction: 0.00
# Walker 593 acceptance fraction: 0.00
# Walker 594 acceptance fraction: 0.00
# Walker 595 acceptance fraction: 0.00
# Walker 596 acceptance fraction: 0.00
# Walker 597 acceptance fraction: 0.00
# Walker 598 acceptance fraction: 0.00
# Walker 599 acceptance fraction: 0.00
# Walker 600 acceptance fraction: 0.00
# Walker 601 acceptance fraction: 0.00
# Walker 602 acceptance fraction: 0.00
# Walker 603 acceptance fraction: 0.00
# Walker 604 acceptance fraction: 0.00
# Walker 605 acceptance fraction: 0.00
# Walker 606 acceptance fraction: 0.00
# Walker 607 acceptance fraction: 0.00
# Walker 608 acceptance fraction: 0.00
# Walker 609 acceptance fraction: 0.00
# Walker 610 acceptance fraction: 0.00
# Walker 611 acceptance fraction: 0.00
# Walker 612 acceptance fraction: 0.00
# Walker 613 acceptance fraction: 0.00
# Walker 614 acceptance fraction: 0.00
# Walker 615 acceptance fraction: 0.00
# Walker 616 acceptance fraction: 0.00
# Walker 617 acceptance fraction: 0.00
# Walker 618 acceptance fraction: 0.00
# Walker 619 acceptance fraction: 0.00
# Walker 620 acceptance fraction: 0.00
# Walker 621 acceptance fraction: 0.00
# Walker 622 acceptance fraction: 0.00
# Walker 623 acceptance fraction: 0.00
# Walker 624 acceptance fraction: 0.00
# Walker 625 acceptance fraction: 0.00
# Walker 626 acceptance fraction: 0.00
# Walker 627 acceptance fraction: 0.00
# Walker 628 acceptance fraction: 0.00
# Walker 629 acceptance fraction: 0.00
# Walker 630 acceptance fraction: 0.00
# Walker 631 acceptance fraction: 0.00
# Walker 632 acceptance fraction: 0.00
# Walker 633 acceptance fraction: 0.00
# Walker 634 acceptance fraction: 0.00
# Walker 635 acceptance fraction: 0.00
# Walker 636 acceptance fraction: 0.00
# Walker 637 acceptance fraction: 0.00
# Walker 638 acceptance fraction: 0.00
# Walker 639 acceptance fraction: 0.00
# Walker 640 acceptance fraction: 0.00
# Walker 641 acceptance fraction: 0.00
# Walker 642 acceptance fraction: 0.00
# Walker 643 acceptance fraction: 0.00
# Walker 644 acceptance fraction: 0.00
# Walker 645 acceptance fraction: 0.00
# Walker 646 acceptance fraction: 0.00
# Walker 647 acceptance fraction: 0.00
# Walker 648 acceptance fraction: 0.00
# Walker 649 acceptance fraction: 0.00
# Walker 650 acceptance fraction: 0.00
# Walker 651 acceptance fraction: 0.00
# Walker 652 acceptance fraction: 0.00
# Walker 653 acceptance fraction: 0.00
# Walker 654 acceptance fraction: 0.00
# Walker 655 acceptance fraction: 0.00
# Walker 656 acceptance fraction: 0.00
# Walker 657 acceptance fraction: 0.00
# Walker 658 acceptance fraction: 0.00
# Walker 659 acceptance fraction: 0.00
# Walker 660 acceptance fraction: 0.00
# Walker 661 acceptance fraction: 0.00
# Walker 662 acceptance fraction: 0.00
# Walker 663 acceptance fraction: 0.00
# Walker 664 acceptance fraction: 0.00
# Walker 665 acceptance fraction: 0.00
# Walker 666 acceptance fraction: 0.00
# Walker 667 acceptance fraction: 0.00
# Walker 668 acceptance fraction: 0.00
# Walker 669 acceptance fraction: 0.00
# Walker 670 acceptance fraction: 0.00
# Walker 671 acceptance fraction: 0.00
# Walker 672 acceptance fraction: 0.00
# Walker 673 acceptance fraction: 0.00
# Walker 674 acceptance fraction: 0.00
# Walker 675 acceptance fraction: 0.00
# Walker 676 acceptance fraction: 0.00
# Walker 677 acceptance fraction: 0.00
# Walker 678 acceptance fraction: 0.00
# Walker 679 acceptance fraction: 0.00
# Walker 680 acceptance fraction: 0.00
# Walker 681 acceptance fraction: 0.00
# Walker 682 acceptance fraction: 0.00
# Walker 683 acceptance fraction: 0.00
# Walker 684 acceptance fraction: 0.00
# Walker 685 acceptance fraction: 0.00
# Walker 686 acceptance fraction: 0.00
# Walker 687 acceptance fraction: 0.00
# Walker 688 acceptance fraction: 0.00
# Walker 689 acceptance fraction: 0.00
# Walker 690 acceptance fraction: 0.00
# Walker 691 acceptance fraction: 0.00
# Walker 692 acceptance fraction: 0.00
# Walker 693 acceptance fraction: 0.00
# Walker 694 acceptance fraction: 0.00
# Walker 695 acceptance fraction: 0.00
# Walker 696 acceptance fraction: 0.00
# Walker 697 acceptance fraction: 0.00
# Walker 698 acceptance fraction: 0.00
# Walker 699 acceptance fraction: 0.00
# Walker 700 acceptance fraction: 0.00
# Walker 701 acceptance fraction: 0.00
# Walker 702 acceptance fraction: 0.00
# Walker 703 acceptance fraction: 0.00
# Walker 704 acceptance fraction: 0.00
# Walker 705 acceptance fraction: 0.00
# Walker 706 acceptance fraction: 0.00
# Walker 707 acceptance fraction: 0.00
# Walker 708 acceptance fraction: 0.00
# Walker 709 acceptance fraction: 0.00
# Walker 710 acceptance fraction: 0.00
# Walker 711 acceptance fraction: 0.00
# Walker 712 acceptance fraction: 0.00
# Walker 713 acceptance fraction: 0.00
# Walker 714 acceptance fraction: 0.00
# Walker 715 acceptance fraction: 0.00
# Walker 716 acceptance fraction: 0.00
# Walker 717 acceptance fraction: 0.00
# Walker 718 acceptance fraction: 0.00
# Walker 719 acceptance fraction: 0.00
# Walker 720 acceptance fraction: 0.00
# Walker 721 acceptance fraction: 0.00
# Walker 722 acceptance fraction: 0.00
# Walker 723 acceptance fraction: 0.00
# Walker 724 acceptance fraction: 0.00
# Walker 725 acceptance fraction: 0.00
# Walker 726 acceptance fraction: 0.00
# Walker 727 acceptance fraction: 0.00
# Walker 728 acceptance fraction: 0.00
# Walker 729 acceptance fraction: 0.00
# Walker 730 acceptance fraction: 0.00
# Walker 731 acceptance fraction: 0.00
# Walker 732 acceptance fraction: 0.00
# Walker 733 acceptance fraction: 0.00
# Walker 734 acceptance fraction: 0.00
# Walker 735 acceptance fraction: 0.00
# Walker 736 acceptance fraction: 0.00
# Walker 737 acceptance fraction: 0.00
# Walker 738 acceptance fraction: 0.00
# Walker 739 acceptance fraction: 0.00
# Walker 740 acceptance fraction: 0.00
# Walker 741 acceptance fraction: 0.00
# Walker 742 acceptance fraction: 0.00
# Walker 743 acceptance fraction: 0.00
# Walker 744 acceptance fraction: 0.00
# Walker 745 acceptance fraction: 0.00
# Walker 746 acceptance fraction: 0.00
# Walker 747 acceptance fraction: 0.00
# Walker 748 acceptance fraction: 0.00
# Walker 749 acceptance fraction: 0.00
# Walker 750 acceptance fraction: 0.00
# Walker 751 acceptance fraction: 0.00
# Walker 752 acceptance fraction: 0.00
# Walker 753 acceptance fraction: 0.00
# Walker 754 acceptance fraction: 0.00
# Walker 755 acceptance fraction: 0.00
# Walker 756 acceptance fraction: 0.00
# Walker 757 acceptance fraction: 0.00
# Walker 758 acceptance fraction: 0.00
# Walker 759 acceptance fraction: 0.00
# Walker 760 acceptance fraction: 0.00
# Walker 761 acceptance fraction: 0.00
# Walker 762 acceptance fraction: 0.00
# Walker 763 acceptance fraction: 0.00
# Walker 764 acceptance fraction: 0.00
# Walker 765 acceptance fraction: 0.00
# Walker 766 acceptance fraction: 0.00
# Walker 767 acceptance fraction: 0.00
# Walker 768 acceptance fraction: 0.00
# Walker 769 acceptance fraction: 0.00
# Walker 770 acceptance fraction: 0.00
# Walker 771 acceptance fraction: 0.00
# Walker 772 acceptance fraction: 0.00
# Walker 773 acceptance fraction: 0.00
# Walker 774 acceptance fraction: 0.00
# Walker 775 acceptance fraction: 0.00
# Walker 776 acceptance fraction: 0.00
# Walker 777 acceptance fraction: 0.00
# Walker 778 acceptance fraction: 0.00
# Walker 779 acceptance fraction: 0.00
# Walker 780 acceptance fraction: 0.00
# Walker 781 acceptance fraction: 0.00
# Walker 782 acceptance fraction: 0.00
# Walker 783 acceptance fraction: 0.00
# Walker 784 acceptance fraction: 0.00
# Walker 785 acceptance fraction: 0.00
# Walker 786 acceptance fraction: 0.00
# Walker 787 acceptance fraction: 0.00
# Walker 788 acceptance fraction: 0.00
# Walker 789 acceptance fraction: 0.00
# Walker 790 acceptance fraction: 0.00
# Walker 791 acceptance fraction: 0.00
# Walker 792 acceptance fraction: 0.00
# Walker 793 acceptance fraction: 0.00
# Walker 794 acceptance fraction: 0.00
# Walker 795 acceptance fraction: 0.00
# Walker 796 acceptance fraction: 0.00
# Walker 797 acceptance fraction: 0.00
# Walker 798 acceptance fraction: 0.00
# Walker 799 acceptance fraction: 0.00
# Walker 800 acceptance fraction: 0.00
# Walker 801 acceptance fraction: 0.00
# Walker 802 acceptance fraction: 0.00
# Walker 803 acceptance fraction: 0.00
# Walker 804 acceptance fraction: 0.00
# Walker 805 acceptance fraction: 0.00
# Walker 806 acceptance fraction: 0.00
# Walker 807 acceptance fraction: 0.00
# Walker 808 acceptance fraction: 0.00
# Walker 809 acceptance fraction: 0.00
# Walker 810 acceptance fraction: 0.00
# Walker 811 acceptance fraction: 0.00
# Walker 812 acceptance fraction: 0.00
# Walker 813 acceptance fraction: 0.00
# Walker 814 acceptance fraction: 0.00
# Walker 815 acceptance fraction: 0.00
# Walker 816 acceptance fraction: 0.00
# Walker 817 acceptance fraction: 0.00
# Walker 818 acceptance fraction: 0.00
# Walker 819 acceptance fraction: 0.00
# Walker 820 acceptance fraction: 0.00
# Walker 821 acceptance fraction: 0.00
# Walker 822 acceptance fraction: 0.00
# Walker 823 acceptance fraction: 0.00
# Walker 824 acceptance fraction: 0.00
# Walker 825 acceptance fraction: 0.00
# Walker 826 acceptance fraction: 0.00
# Walker 827 acceptance fraction: 0.00
# Walker 828 acceptance fraction: 0.00
# Walker 829 acceptance fraction: 0.00
# Walker 830 acceptance fraction: 0.00
# Walker 831 acceptance fraction: 0.00
# Walker 832 acceptance fraction: 0.00
# Walker 833 acceptance fraction: 0.00
# Walker 834 acceptance fraction: 0.00
# Walker 835 acceptance fraction: 0.00
# Walker 836 acceptance fraction: 0.00
# Walker 837 acceptance fraction: 0.00
# Walker 838 acceptance fraction: 0.00
# Walker 839 acceptance fraction: 0.00
# Walker 840 acceptance fraction: 0.00
# Walker 841 acceptance fraction: 0.00
# Walker 842 acceptance fraction: 0.00
# Walker 843 acceptance fraction: 0.00
# Walker 844 acceptance fraction: 0.00
# Walker 845 acceptance fraction: 0.00
# Walker 846 acceptance fraction: 0.00
# Walker 847 acceptance fraction: 0.00
# Walker 848 acceptance fraction: 0.00
# Walker 849 acceptance fraction: 0.00
# Walker 850 acceptance fraction: 0.00
# Walker 851 acceptance fraction: 0.00
# Walker 852 acceptance fraction: 0.00
# Walker 853 acceptance fraction: 0.00
# Walker 854 acceptance fraction: 0.00
# Walker 855 acceptance fraction: 0.00
# Walker 856 acceptance fraction: 0.00
# Walker 857 acceptance fraction: 0.00
# Walker 858 acceptance fraction: 0.00
# Walker 859 acceptance fraction: 0.00
# Walker 860 acceptance fraction: 0.00
# Walker 861 acceptance fraction: 0.00
# Walker 862 acceptance fraction: 0.00
# Walker 863 acceptance fraction: 0.00
# Walker 864 acceptance fraction: 0.00
# Walker 865 acceptance fraction: 0.00
# Walker 866 acceptance fraction: 0.00
# Walker 867 acceptance fraction: 0.00
# Walker 868 acceptance fraction: 0.00
# Walker 869 acceptance fraction: 0.00
# Walker 870 acceptance fraction: 0.00
# Walker 871 acceptance fraction: 0.00
# Walker 872 acceptance fraction: 0.00
# Walker 873 acceptance fraction: 0.00
# Walker 874 acceptance fraction: 0.00
# Walker 875 acceptance fraction: 0.00
# Walker 876 acceptance fraction: 0.00
# Walker 877 acceptance fraction: 0.00
# Walker 878 acceptance fraction: 0.00
# Walker 879 acceptance fraction: 0.00
# Walker 880 acceptance fraction: 0.00
# Walker 881 acceptance fraction: 0.00
# Walker 882 acceptance fraction: 0.00
# Walker 883 acceptance fraction: 0.00
# Walker 884 acceptance fraction: 0.00
# Walker 885 acceptance fraction: 0.00
# Walker 886 acceptance fraction: 0.00
# Walker 887 acceptance fraction: 0.00
# Walker 888 acceptance fraction: 0.00
# Walker 889 acceptance fraction: 0.00
# Walker 890 acceptance fraction: 0.00
# Walker 891 acceptance fraction: 0.00
# Walker 892 acceptance fraction: 0.00
# Walker 893 acceptance fraction: 0.00
# Walker 894 acceptance fraction: 0.00
# Walker 895 acceptance fraction: 0.00
# Walker 896 acceptance fraction: 0.00
# Walker 897 acceptance fraction: 0.00
# Walker 898 acceptance fraction: 0.00
# Walker 899 acceptance fraction: 0.00
# Walker 900 acceptance fraction: 0.00
# Walker 901 acceptance fraction: 0.00
# Walker 902 acceptance fraction: 0.00
# Walker 903 acceptance fraction: 0.00
# Walker 904 acceptance fraction: 0.00
# Walker 905 acceptance fraction: 0.00
# Walker 906 acceptance fraction: 0.00
# Walker 907 acceptance fraction: 0.00
# Walker 908 acceptance fraction: 0.00
# Walker 909 acceptance fraction: 0.00
# Walker 910 acceptance fraction: 0.00
# Walker 911 acceptance fraction: 0.00
# Walker 912 acceptance fraction: 0.00
# Walker 913 acceptance fraction: 0.00
# Walker 914 acceptance fraction: 0.00
# Walker 915 acceptance fraction: 0.00
# Walker 916 acceptance fraction: 0.00
# Walker 917 acceptance fraction: 0.00
# Walker 918 acceptance fraction: 0.00
# Walker 919 acceptance fraction: 0.00
# Walker 920 acceptance fraction: 0.00
# Walker 921 acceptance fraction: 0.00
# Walker 922 acceptance fraction: 0.00
# Walker 923 acceptance fraction: 0.00
# Walker 924 acceptance fraction: 0.00
# Walker 925 acceptance fraction: 0.00
# Walker 926 acceptance fraction: 0.00
# Walker 927 acceptance fraction: 0.00
# Walker 928 acceptance fraction: 0.00
# Walker 929 acceptance fraction: 0.00
# Walker 930 acceptance fraction: 0.00
# Walker 931 acceptance fraction: 0.00
# Walker 932 acceptance fraction: 0.00
# Walker 933 acceptance fraction: 0.00
# Walker 934 acceptance fraction: 0.00
# Walker 935 acceptance fraction: 0.00
# Walker 936 acceptance fraction: 0.00
# Walker 937 acceptance fraction: 0.00
# Walker 938 acceptance fraction: 0.00
# Walker 939 acceptance fraction: 0.00
# Walker 940 acceptance fraction: 0.00
# Walker 941 acceptance fraction: 0.00
# Walker 942 acceptance fraction: 0.00
# Walker 943 acceptance fraction: 0.00
# Walker 944 acceptance fraction: 0.00
# Walker 945 acceptance fraction: 0.00
# Walker 946 acceptance fraction: 0.00
# Walker 947 acceptance fraction: 0.00
# Walker 948 acceptance fraction: 0.00
# Walker 949 acceptance fraction: 0.00
# Walker 950 acceptance fraction: 0.00
# Walker 951 acceptance fraction: 0.00
# Walker 952 acceptance fraction: 0.00
# Walker 953 acceptance fraction: 0.00
# Walker 954 acceptance fraction: 0.00
# Walker 955 acceptance fraction: 0.00
# Walker 956 acceptance fraction: 0.00
# Walker 957 acceptance fraction: 0.00
# Walker 958 acceptance fraction: 0.00
# Walker 959 acceptance fraction: 0.00
# Walker 960 acceptance fraction: 0.00
# Walker 961 acceptance fraction: 0.00
# Walker 962 acceptance fraction: 0.00
# Walker 963 acceptance fraction: 0.00
# Walker 964 acceptance fraction: 0.00
# Walker 965 acceptance fraction: 0.00
# Walker 966 acceptance fraction: 0.00
# Walker 967 acceptance fraction: 0.00
# Walker 968 acceptance fraction: 0.00
# Walker 969 acceptance fraction: 0.00
# Walker 970 acceptance fraction: 0.00
# Walker 971 acceptance fraction: 0.00
# Walker 972 acceptance fraction: 0.00
# Walker 973 acceptance fraction: 0.00
# Walker 974 acceptance fraction: 0.00
# Walker 975 acceptance fraction: 0.00
# Walker 976 acceptance fraction: 0.00
# Walker 977 acceptance fraction: 0.00
# Walker 978 acceptance fraction: 0.00
# Walker 979 acceptance fraction: 0.00
# Walker 980 acceptance fraction: 0.00
# Walker 981 acceptance fraction: 0.00
# Walker 982 acceptance fraction: 0.00
# Walker 983 acceptance fraction: 0.00
# Walker 984 acceptance fraction: 0.00
# Walker 985 acceptance fraction: 0.00
# Walker 986 acceptance fraction: 0.00
# Walker 987 acceptance fraction: 0.00
# Walker 988 acceptance fraction: 0.00
# Walker 989 acceptance fraction: 0.00
# Walker 990 acceptance fraction: 0.00
# Walker 991 acceptance fraction: 0.00
# Walker 992 acceptance fraction: 0.00
# Walker 993 acceptance fraction: 0.00
# Walker 994 acceptance fraction: 0.00
# Walker 995 acceptance fraction: 0.00
# Walker 996 acceptance fraction: 0.00
# Walker 997 acceptance fraction: 0.00
# Walker 998 acceptance fraction: 0.00
# Walker 999 acceptance fraction: 0.00
# Walker 1000 acceptance fraction: 0.00

# %% [markdown]
# # Define prior distributions (replace with your knowledge about mass & period)
# #add v prior so model can compare its values to it.
# vr_prior = norm( loc=1144.188354, scale=10)
# mass1_prior = norm(loc=1e35, scale=1e30)  # Assuming a normal prior for mass with mean 1e41 kg (approx 5e10 M) standard dev: random
# mass2_prior = norm(loc=1e35, scale=1e30)
# period_prior = norm(loc=8e37, scale=1e30)  # Assuming a normal prior for period with mean 1e5 years and std 1e4 years
#
# # Monte Carlo loop
# n_simulations = 1000  # Number of simulations
# masses = np.zeros(n_simulations)
# periods = np.zeros(n_simulations)
# accepted = 0
#
# for i in range(n_simulations):
#     # Draw samples from priors
#     m2 = mass2_prior.rvs()
#     m1 = mass1_prior.rvs()
#     p = period_prior.rvs()
#     vrp=vr_prior.rvs()
#
#     # Simulate OIII line data with the model
#     simulated_v = smbh2_model(p, m1, m2)
#
#     # Likelihood function
#     # This should compare the simulated data with our actual OIII line data (flux vs wavelength)
#     # and calculate the probability of getting the observed data given the model parameters
#     likelihood = np.exp(-np.sum((vrp - simulated_v)**2))
#
#     # Acceptance probability (Metropolis-Hastings)
#     acceptance_ratio = likelihood * period_prior.pdf(p) * mass2_prior.pdf(m2)*mass1_prior.pdf(m1)
#
#     # Random number for acceptance decision
#     u = np.random.rand()
#
#     if u < acceptance_ratio:
#         masses[i] = m2
#         periods[i] = p
#         accepted += 1
#
# # Analyze results
# accepted_fraction = accepted / n_simulations
# print(f"Acceptance fraction: {accepted_fraction:.4f}")
#
# # Extract posterior distribution for mass and period
# mass_posterior = np.histogram(masses, bins=20)[0] / n_simulations
# period_posterior = np.histogram(periods, bins=20)[0] / n_simulations
#
# # Plot results (optional)
# plt.hist(masses, bins=20, label="Mass Posterior")
# plt.legend()
# plt.show()
#
# plt.hist(periods, bins=20, label="Period Posterior")
# plt.legend()
# plt.show()
#
# # Find maximum a posteriori (MAP) estimates
# map_mass = masses[np.argmax(mass_posterior)]
# map_period = periods[np.argmax(period_posterior)]
#
# print(likelihood)
# print(acceptance_ratio)
# print(vrp)
# print(simulated_v)
# print(f"MAP Mass: {map_mass:.2e} solar masses")
# print(f"MAP Period: {map_period:.2e} years")
